# %%
import pickle
with open(r"D:\vscode_workspace\ZhongYiPapers\manual_labeling_html\Database\user_queue.pickle", "rb") as file:
    user_queue = pickle.load(file)
with open(r"D:\vscode_workspace\ZhongYiPapers\manual_labeling_html\Database\item_queue.pickle", "rb") as file:
    item_queue = pickle.load(file)
with open(r"D:\vscode_workspace\ZhongYiPapers\manual_labeling_html\Database\user_dict.pickle", "rb") as file:
    user_dict = pickle.load(file)

# %%
user_queue, item_queue
# Out:
# ({'L': '1052fc47efc30d4f4555324c4275f8358cf6d0bc34ac8e5a8c6a88938c51fda1'},
#  ['1542ae4029c5941fba50938acc5c7a5baa508a3d40744a2e741da8e2e686f3d3',
#   'd42652234a58e5b1d496f60bb566d0e03fbd4f63efcd6c1a6aec76697016608a',
#   '05fe3dd612ab623dddf908cc746d632a0497528e7271fdacd88710a7549a9118',
#   '3b67c33e43b5adbb47be37b0be43f62044fadedcc28386b541343c9bb965a3c7',
#   '9d8db0dec7f7dc951c7949e4c319c3acd20e3bf5a483fd91f37651858e0d45b7',
#   'c1110f2bcfb9fc547aa780156a24e00d793d9a082203cbf0ddb3278261d3450a',
#   'ae6bd0af3cf5cdb4915534a944c54963f5f6d9801536d35bbfd3d6ec571a877e',
#   '173a40e55ebf5766ae719fe6d65b65f1bd559bdf00e8cedc7ed152c2dc7b61db',
#   '147d4b08ed20013c1ba7a3a44c4964a534381a83b2f0a25cc561aa8d9b910fc0',
#   'be355433fb98a723e8b1971d2158727dd93d5e813b85398c4122a506157a14bb',
#   '724130fc54dfd5ab69b0d022b13cba931f878ad25e554179b62360b61e8688e7',
#   '0f371ab3a1b959617688ed8fcf02ff89d0c986dc227f927da7b8a96aa2e974ac',
# ...

# %%
user_dict
# Out:
# {'L': {'uid_list': ['cb14b15492121ba86ab79b895889a9f2459274abaf90eba94e144d2906468e01',
#    'a5ff0a3eda601af1ec885505ae3897066ac4c1143334aa054f7f0648eb3f295c',
#    '32900ba449dbefac15d5b5ba82d68971c787f65241ec3923e59504994774a9da',
#    '25e03d4cfa8e44b48138adf004455beb36115b3f1cf47b8baade7095e8177a31',
#    'a5ff0a3eda601af1ec885505ae3897066ac4c1143334aa054f7f0648eb3f295c',
#    'bdcd15d6ded99421421925e65e35c19ae2ef161c281372276aa097ee635d5c63',
#    'b45417997bcb8c1250a8c26254cd341b1f897e1647044daf451733840e71abc2',
#    '421d8bd3b4dbea4fbaa30b198cbd706642fccce41aebc96518745cf3df0eb6b6',
#    '681255c7157f5d3a3a5de48d56ca346f175aadde993083dae997dfd2f86083bc',
#    'b45417997bcb8c1250a8c26254cd341b1f897e1647044daf451733840e71abc2',
#    'ce08ce6aed568828765fed78e640fd44dde321a5e6a6f93943ca652db60f479f'],
#   'records': {'ce08ce6aed568828765fed78e640fd44dde321a5e6a6f93943ca652db60f479f': [{'UserName': 'L',
# ...
